# %% [markdown]
# ### Osama Kamal | SPARKS Intern for Data Science and Business Analytics

# %% [markdown]
# ## Task 1: Prediction Using Decision Tree Algorithm

# %% [markdown]
# We are going to demonstrate Decision Teee Classification on the dataset of Iris with the help of PyCaret ML library

# %% [markdown]
# ### Importing Data

# %%
import pandas as pd
import numpy as np
import os
file_path = os.path.abspath('./Users/Lenovo/Iris.csv')
print(file_path)
# Out:
# C:\Users\Lenovo\Users\Lenovo\Iris.csv

# %%
data=pd.read_csv('Iris.csv')
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ### Setting up the Environment

# %%
from pycaret.classification import *
dec1 = setup(data, target='Species')
# Out:
# <style  type="text/css" >
# </style><table id="T_e611a554_3e57_11eb_b393_507b9d59c615" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e611a554_3e57_11eb_b393_507b9d59c615level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e611a554_3e57_11eb_b393_507b9d59c615row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_e611a554_3e57_11eb_b393_507b9d59c615row0_col1" class="data row0 col1" >2900</td>
#             </tr>
#             <tr>
#                         <th id="T_e611a554_3e57_11eb_b393_507b9d59c615level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_e611a554_3e57_11eb_b393_507b9d59c615row1_col0" class="data row1 col0" >Target</td>
# ...

# %% [markdown]
# ### Compare Models

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_f795c57d_3e57_11eb_9645_507b9d59c615 th {
#           text-align: left;
# ...

# %% [markdown]
# We will be using Decision Tree for this classification problem

# %% [markdown]
# ### Create Model

# %%
dt = create_model('dt')
# Out:
# <style  type="text/css" >
# #T_f7e4256e_3e57_11eb_86cf_507b9d59c615row10_col0,#T_f7e4256e_3e57_11eb_86cf_507b9d59c615row10_col1,#T_f7e4256e_3e57_11eb_86cf_507b9d59c615row10_col2,#T_f7e4256e_3e57_11eb_86cf_507b9d59c615row10_col3,#T_f7e4256e_3e57_11eb_86cf_507b9d59c615row10_col4,#T_f7e4256e_3e57_11eb_86cf_507b9d59c615row10_col5,#T_f7e4256e_3e57_11eb_86cf_507b9d59c615row10_col6{
#             background:  yellow;
#         }</style><table id="T_f7e4256e_3e57_11eb_86cf_507b9d59c615" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %% [markdown]
# ### Evaluate Model

# %%
evaluate_model(dt)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…
